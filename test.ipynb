# %% [markdown]
# Example: Shign on DINA1

# %%
import ShignPipeline as SP

audio_path = "input/DINA2_PlaySession1_IDS1.mp3"
video_path = "input/DINA2_Play1.mov"
pad = True
pad_mode = "video"

SP.script(audio_path, video_path, pad=pad, pad_mode=pad_mode)
# Out:
# [src/libmpg123/layer3.c:III_get_side_info():255] error: Blocktype == 0 and window-switching == 1 not allowed.
# [src/libmpg123/layer3.c:INT123_do_layer3():1853] error: bad frame - unable to get valid sideinfo
# /home/chengyi/Projects/TranscriptPipeline/ShignPipeline.py:117: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_2, sr_2 = librosa.load(inputfile2, sr=None)
# 44825.0 milliseconds needs to be added to the beginning of input/DINA1_Play2.mov
# Padding files accordingly...
# input/DINA1_Play2.mov will be padded
# MoviePy - Writing audio in input/shigned_DINA1_Playsession2_IDS2.mp3
# MoviePy - Done.
# MoviePy - Building video input/shigned_DINA1_Play2.mov.
# MoviePy - Writing audio in shigned_DINA1_Play2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video input/shigned_DINA1_Play2.mov
# MoviePy - Done !
# MoviePy - video ready input/shigned_DINA1_Play2.mov

# %% [markdown]
# - DINA1_Play1: The alignment works fine.
# - DINA1_Play2: The alignment did not do well. There's some corrected audio near the start of the video file.

# %% [markdown]
# Example: WhisperX

# %%
import AlignPipeline as AP
from lingua import Language
import json

# Set variables & specify tier with utterances
audio_path = 'input/INTEL052V3S_Formatted.wav'
json_path = 'input/INTEL052V3S_Formatted.json'
output_dir = 'output/'
